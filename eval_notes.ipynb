# %%
from Evaluation import test

# %%
tests = test.load_tests()

# %%
example = tests[0]
print(example.question)
print(example.category)
print(example.reference_answer)
print(example.keywords)
# Out:
# What is the order cut-off time for same-day Express delivery in Dubai?
# direct_fact
# For Dubai and Abu Dhabi, the order cut-off for same-day Express delivery is 12:00 PM, with delivery occurring between 16:00 and 22:00.
# ['12:00 PM', 'Express', 'Dubai', 'same-day']

# %%
from collections import Counter
count = Counter([t.category for t in tests])
count
# Out:
# Counter({'policy_governance': 22,
#          'direct_fact': 15,
#          'loyalty_program': 11,
#          'technical_constraint': 10,
#          'policy_boundary': 9,
#          'policy_exclusion': 7,
#          'product_specifications': 7,
#          'multi_step_reasoning': 6,
#          'technical_troubleshooting': 5,
#          'product_safety': 4,
#          'technical_governance': 4,
#          'security_protocol': 4,
#          'technical_maintenance': 4,
#          'mathematical_logic': 2})

# %%
from Evaluation.eval import evaluate_retrieval, evaluate_answer

# %%
evaluate_retrieval(example)
# Out:
# RetrievalEval(mrr=1.0, ndcg=0.9048750308285421, keywords_found=4, total_keywords=4, keyword_coverage=100.0)

# %%
eval, answer, chunks, stats = evaluate_answer(example)

# %%
eval
# Out:
# AnswerEval(feedback='The answer correctly states the cut-off time at 12:00 PM but omits the mention of Abu Dhabi and the delivery window, which are included in the reference. It is relevant but not entirely complete.', accuracy=4.0, completeness=3.0, relevance=5.0)

# %%
stats
# Out:
# {'total_tokens': 1313,
#  'prompt_tokens': 1291,
#  'completion_tokens': 22,
#  'total_cost_usd': 0.0001379}

# %%
print(eval.feedback)
print(eval.accuracy)
print(eval.completeness)
print(eval.relevance)
# Out:
# The answer correctly states the cut-off time at 12:00 PM but omits the mention of Abu Dhabi and the delivery window, which are included in the reference. It is relevant but not entirely complete.
# 4.0
# 3.0
# 5.0
